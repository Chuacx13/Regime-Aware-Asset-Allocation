# %%
from RegimeAwareAllocator import RegimeAwareAllocator

# %%
allocator = RegimeAwareAllocator(start_date="2005-01-01", out_of_sample_years=2, verbose=False)
allocator.fetch_asset_data()
allocator.preprocess_features()
best_k = allocator.optimize_n_components_by_bic(window=1000)
allocator.identify_regimes(window=1000, n_components=best_k)          
allocator.combine_regimes_to_features() 
allocator.convert_log_to_simple_returns()
allocator.plot_regime_distribution() 
allocator.plot_transition_likelihood() 
allocator.shift_returns()
weights = allocator.compute_all_regime_weights()

allocator.calculate_regime_aware_max_sharpe_is(weights_df=weights)
allocator.calculate_rolling_rpp_is()
allocator.calculate_rolling_max_sharpe_is()
allocator.calculate_6040_is()
print("In-Sample Performance:")
allocator.plot_cumulative_wealth(allocator.is_returns)
allocator.print_metrics(allocator.is_returns)

allocator.calculate_regime_aware_max_sharpe_oos(weights_df=weights)
allocator.calculate_rolling_rpp_oos()
allocator.calculate_rolling_max_sharpe_oos()
allocator.calculate_6040_oos()
print("Out-of-Sample Performance:")
allocator.plot_cumulative_wealth(allocator.oos_returns)
allocator.print_metrics(allocator.oos_returns)
# Out:
# Fetching asset prices from yfinance...
# c:\Users\chuac\Downloads\Regime-Aware Multi-Asset Strategy\RegimeAwareAllocator.py:57: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   px = yf.download(list(self.assets_series.values()), start=self.start_date, end=self.end_date_oos)['Close']
# [*********************100%***********************]  5 of 5 completed
# Prices fetched: (5202, 5)
# ==================================================
# Fetching macro data from FRED...
# Macro data fetched: (13375, 6)
# ==================================================
# Preprocessing features...
# Features ready: 4639 rows × 13 columns
# ==================================================
# Optimizing number of GMM components using average BIC...
# Average BIC per k:
#   k = 2: avg BIC = 25275.62
#   k = 3: avg BIC = 21886.38
#   k = 4: avg BIC = 19571.93
# Best number of components based on average BIC: 4
# ==================================================
# Identifying regimes...
# Regime identification complete. 4 regimes detected.
# ==================================================
# Combining regimes to feature df
# ==================================================
# Converting log returns to simple returns for assets...
# ==================================================
# Plotting regime distribution...
# regime           0.0        1.0        2.0        3.0
# ret_GOLD   -0.000435   0.000376   0.000026  -0.000240
# ret_BONDS   0.000254   0.000141  -0.000288   0.000012
# ret_SPY    -0.000137   0.000722   0.001488   0.000041
# ret_USD     0.000301   0.000027   0.000251   0.000232
# vol_GOLD    0.010524   0.009066   0.011163   0.008517
# vol_BONDS   0.004209   0.003511   0.004733   0.004065
# vol_SPY     0.014369   0.008498   0.012954   0.009264
# vol_USD     0.004807   0.004081   0.005459   0.004490
# VIX        26.153487  17.191211  22.597703  18.318818
# CPI_YoY     0.027927   0.023180   0.034825   0.028116
# GDP_YoY     0.001541   0.018643   0.025201   0.026881
# UNRATE      7.428289   5.747448   6.880180   4.914642
# T10Y2Y      1.004145   1.067345   0.959910   0.883655
# Regime distribution (%):
#         Percentage
# regime
# 0.0           4.84
# 1.0          58.70
# 2.0           7.07
# 3.0          29.38
# ==================================================
# Transition likelihood (%):
#         Percentage
# regime
# 0 → 0         4.46
# 0 → 1         0.19
# 0 → 2         0.10
# 0 → 3         0.10
# 1 → 0         0.22
# 1 → 1        57.22
# 1 → 2         0.26
# 1 → 3         1.02
# 2 → 0         0.03
# 2 → 1         0.32
# 2 → 2         6.63
# 2 → 3         0.10
# 3 → 0         0.13
# 3 → 1         0.96
# 3 → 2         0.10
# 3 → 3        28.18
# ==================================================
# Shifting returns by -1
# ==================================================
# Computed weights for asset allocation in different regimes:
#               0         1         2         3
# SPY    0.195361  0.598000  0.666183  0.287131
# BONDS  0.647915  0.331620 -0.245615  0.073209
# GOLD  -0.213453  0.163126 -0.004848 -0.360341
# USD    0.370178 -0.092745  0.584280  1.000000
# Calculating in-sample regime-aware max Sharpe returns...
# ==================================================
# Calculating in-sample rolling RPP returns...
# Calculating in-sample rolling max Sharpe returns...
# Calculating in-sample 60/40 portfolio returns...
# ==================================================
# In-Sample Performance:
# Plotting cumulative wealth ...
# Computing Performance Metrics ...
# Performance Metrics
#              regime_max_sharpe rolling_rpp rolling_max_sharpe    60_40
# n_days                    2885        2885               2885     2885
# ann_return              11.17%       4.10%              6.71%    8.35%
# ann_vol                 10.51%       5.47%              8.27%    9.89%
# sharpe                    1.06        0.76               0.83     0.86
# sortino                   1.58        1.09               1.15     1.21
# max_drawdown           -11.02%     -13.86%            -16.71%  -21.02%
# var_5                   -1.01%      -0.52%             -0.77%   -0.89%
# cvar_5                  -1.49%      -0.82%             -1.33%   -1.50%
# skewness                  0.34       -0.20              -0.65    -0.43
# kurtosis                 14.29       16.81              11.38    14.84
# ==================================================
# Calculating out-of-sample regime-aware max Sharpe returns...
# ==================================================
# Calculating out-of-sample rolling RPP returns...
# c:\Users\chuac\Downloads\Regime-Aware Multi-Asset Strategy\RegimeAwareAllocator.py:690: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.17%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   fmt.loc["ann_return", c]   = f"{100 * df.loc['ann_return', c]:.2f}%"
# c:\Users\chuac\Downloads\Regime-Aware Multi-Asset Strategy\RegimeAwareAllocator.py:690: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.10%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   fmt.loc["ann_return", c]   = f"{100 * df.loc['ann_return', c]:.2f}%"
# c:\Users\chuac\Downloads\Regime-Aware Multi-Asset Strategy\RegimeAwareAllocator.py:690: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.71%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   fmt.loc["ann_return", c]   = f"{100 * df.loc['ann_return', c]:.2f}%"
# c:\Users\chuac\Downloads\Regime-Aware Multi-Asset Strategy\RegimeAwareAllocator.py:690: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.35%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   fmt.loc["ann_return", c]   = f"{100 * df.loc['ann_return', c]:.2f}%"
# Calculating out-of-sample rolling max Sharpe returns...
# Calculating out-of-sample 60/40 portfolio returns...
# ==================================================
# Out-of-Sample Performance:
# Plotting cumulative wealth ...
# Computing Performance Metrics ...
# Performance Metrics
#              regime_max_sharpe rolling_rpp rolling_max_sharpe    60_40
# n_days                     247         247                247      247
# ann_return               9.02%       9.85%              9.19%   12.79%
# ann_vol                 11.67%       6.65%              4.55%   11.90%
# sharpe                    0.80        1.45               1.96     1.07
# sortino                   1.05        2.24               2.96     1.63
# max_drawdown           -18.16%      -4.28%             -2.62%  -10.61%
# var_5                   -1.09%      -0.58%             -0.46%   -0.97%
# cvar_5                  -1.83%      -0.91%             -0.60%   -1.69%
# skewness                 -1.29        1.14              -0.05     1.34
# kurtosis                  9.11       18.95               4.64    22.78
# ==================================================
# c:\Users\chuac\Downloads\Regime-Aware Multi-Asset Strategy\RegimeAwareAllocator.py:690: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.02%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   fmt.loc["ann_return", c]   = f"{100 * df.loc['ann_return', c]:.2f}%"
# c:\Users\chuac\Downloads\Regime-Aware Multi-Asset Strategy\RegimeAwareAllocator.py:690: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.85%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   fmt.loc["ann_return", c]   = f"{100 * df.loc['ann_return', c]:.2f}%"
# c:\Users\chuac\Downloads\Regime-Aware Multi-Asset Strategy\RegimeAwareAllocator.py:690: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.19%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   fmt.loc["ann_return", c]   = f"{100 * df.loc['ann_return', c]:.2f}%"
# c:\Users\chuac\Downloads\Regime-Aware Multi-Asset Strategy\RegimeAwareAllocator.py:690: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12.79%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   fmt.loc["ann_return", c]   = f"{100 * df.loc['ann_return', c]:.2f}%"

# %%
sims = allocator.simulate_block_bootstrap_mc(n_sims=5000)
mc_summary = allocator.summarize_mc(sims)
mc_vs_oos = allocator.compare_mc_vs_actual_oos(sims)

allocator.plot_mc_wealth_fan(sims, strategy_name='regime_max_sharpe')
allocator.plot_mc_sharpe_hist(sims, strategy_name='regime_max_sharpe')
# Out:
# Simulating Block Bootstrap Monte Carlo...
# Computed weights for asset allocation in different regimes:
#               0         1         2         3
# SPY    0.195361  0.598000  0.666183  0.287131
# BONDS  0.647915  0.331620 -0.245615  0.073209
# GOLD  -0.213453  0.163126 -0.004848 -0.360341
# USD    0.370178 -0.092745  0.584280  1.000000
# Simulation complete
# ==================================================
#                  60_40                                                  \
#                   mean     std       p05       p25       p50       p75
# n_days        500.0000  0.0000  500.0000  500.0000  500.0000  500.0000
# ann_return      0.0881  0.0696   -0.0275    0.0424    0.0890    0.1352
# ann_vol         0.0988  0.0196    0.0749    0.0852    0.0941    0.1066
# sharpe          0.9571  0.7086   -0.1903    0.4579    0.9500    1.4428
# sortino         1.4224  1.0942   -0.2475    0.6326    1.3578    2.1411
# max_drawdown   -0.1096  0.0500   -0.2074   -0.1327   -0.0951   -0.0740
# var_5          -0.0094  0.0017   -0.0126   -0.0106   -0.0092   -0.0082
# cvar_5         -0.0151  0.0036   -0.0226   -0.0164   -0.0142   -0.0126
# skewness       -0.3048  0.5748   -1.1382   -0.6295   -0.3613   -0.0412
# kurtosis        8.8094  4.6535    4.3489    5.4825    7.0510   10.4195
#
#                        regime_max_sharpe                              \
#                    p95              mean     std       p05       p25
# n_days        500.0000          500.0000  0.0000  500.0000  500.0000
# ann_return      0.1997            0.1201  0.0704    0.0099    0.0710
# ann_vol         0.1384            0.1045  0.0172    0.0844    0.0926
# sharpe          2.1161            1.1446  0.6288    0.1470    0.7092
# sortino         3.2862            1.7473  1.0244    0.1991    1.0252
# max_drawdown   -0.0506           -0.0922  0.0312   -0.1507   -0.1081
# var_5          -0.0070           -0.0098  0.0013   -0.0119   -0.0108
# cvar_5         -0.0107           -0.0148  0.0024   -0.0194   -0.0162
# skewness        0.7907            0.1141  0.5450   -0.6111   -0.2938
# kurtosis       19.0877            8.8336  5.7126    4.2009    5.1233
#
#
#                    p50       p75       p95
# n_days        500.0000  500.0000  500.0000
# ann_return      0.1171    0.1659    0.2408
# ann_vol         0.0999    0.1114    0.1389
# sharpe          1.1273    1.5476    2.1869
# sortino         1.6650    2.3750    3.5445
# max_drawdown   -0.0879   -0.0693   -0.0527
# var_5          -0.0099   -0.0088   -0.0078
# cvar_5         -0.0143   -0.0131   -0.0115
# skewness       -0.0371    0.5726    1.0695
# kurtosis        6.3322    9.9087   22.2030
# ==================================================
# ==================================================
# Monte Carlo vs Actual OOS Performance: **60_40**
#  ann_return     : Actual =   0.1279 | MC Percentile Rank =  63.90%
#  ann_vol        : Actual =   0.1190 | MC Percentile Rank =  86.72%
#  sharpe         : Actual =   1.0700 | MC Percentile Rank =  51.72%
#  sortino        : Actual =   1.6312 | MC Percentile Rank =  53.58%
#  max_drawdown   : Actual =  -0.1061 | MC Percentile Rank =  20.24%
#  var_5          : Actual =  -0.0097 | MC Percentile Rank =  36.00%
#  cvar_5         : Actual =  -0.0169 | MC Percentile Rank =  18.60%
#  skewness       : Actual =   1.3350 | MC Percentile Rank =  96.74%
#  kurtosis       : Actual =  22.7833 | MC Percentile Rank =  99.84%
# ==================================================
# ==================================================
# Monte Carlo vs Actual OOS Performance: **REGIME_MAX_SHARPE**
#  ann_return     : Actual =   0.0902 | MC Percentile Rank =  38.88%
#  ann_vol        : Actual =   0.1167 | MC Percentile Rank =  82.94%
#  sharpe         : Actual =   0.7984 | MC Percentile Rank =  34.04%
#  sortino        : Actual =   1.0540 | MC Percentile Rank =  31.02%
#  max_drawdown   : Actual =  -0.1816 | MC Percentile Rank =   0.34%
#  var_5          : Actual =  -0.0109 | MC Percentile Rank =  26.60%
#  cvar_5         : Actual =  -0.0183 | MC Percentile Rank =  11.14%
#  skewness       : Actual =  -1.2899 | MC Percentile Rank =   0.28%
#  kurtosis       : Actual =   9.1096 | MC Percentile Rank =  81.14%
# ==================================================
